# %% [markdown]
# # first 2 cels optional

# %%
# Command line:  

# for year in `seq 1998 2008`;do for month in `seq 1 12`;do wget --content-disposition "http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=1706&Year=${year}&Month=${month}&Day=14&timeframe=1&submit= Download+Data" ;done;done


# WHERE; 
# • year = change values in command line (`seq 1998 2008)
# • month = change values in command line (`seq 1 12)
# • format= [csv|xml]: the format output
# • timeframe = 1: for hourly data 
# • timeframe = 2: for daily data 
# • timeframe = 3 for monthly data 
# • Day: the value of the "day" variable is not used and can be an arbitrary value 
# • For another station, change the value of the variable stationID
# • For the data in XML format, change the value of the variable format to xml in the URL. 

import urllib.request

req = urllib.request.Request('http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2020&Month=5&Day=17&timeframe=2&submit=Download+Data')
with urllib.request.urlopen(req) as response:
   the_page = response.read()

print(the_page.decode())

# %%
import pandas as pd

# weatherDF=pd.DataFrame()

# weatherDF.info
url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2020&Month=9&Day=12&timeframe=2&submit=Download+Data"
print(url)
tempweather=pd.read_csv(url,skiprows=0)
# print(c)
print(tempweather.head())
print(tempweather.tail())
#     url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year="+str(x)+"&Month=5&Day=19&timeframe=2&submit=Download+Data"
#     print(url)
#     c=pd.read_csv(url,skiprows=25)
#     weatherDF.append(c,ignore_index=True) 
# #     print("this is c ",c)

# print('the appended ',weatherDF)

# %% [markdown]
# # Update starts here

# %%
import pandas as pd

weatherDF=pd.DataFrame()

# weatherDF.info
# url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2017&Month=5&Day=19&timeframe=2&submit=Download+Data"
# print(url)
# tempweather17=pd.read_csv(url,skiprows=0)
# print('\n2017 \n',tempweather17.count(),'\n',tempweather17.head(),tempweather17.tail())

# url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2018&Month=5&Day=19&timeframe=2&submit=Download+Data"
# print(url)
# tempweather18=pd.read_csv(url,skiprows=0)
# print('\n2018 \n',tempweather18.count(),'\n',tempweather18.head(),tempweather18.tail())

# url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2019&Month=5&Day=19&timeframe=2&submit=Download+Data"
# print(url)
# tempweather19=pd.read_csv(url,skiprows=0)
# print('\n2019 \n',tempweather19.count(),'\n',tempweather19.head(),tempweather19.tail())

url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2020&Month=5&Day=19&timeframe=2&submit=Download+Data"
print(url)
tempweather20=pd.read_csv(url,skiprows=0)
print('\n2020 \n',tempweather20.count(),'\n',tempweather20.head(),tempweather20.tail())
# Out:
# http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2020&Month=5&Day=19&timeframe=2&submit=Download+Data
#
# 2020
#  Longitude (x)                366
# Latitude (y)                 366
# Station Name                 366
# Climate ID                   366
# Date/Time                    366
# Year                         366
# Month                        366
# Day                          366
# Data Quality                   0
# Max Temp (°C)                250
# Max Temp Flag                  8
# Min Temp (°C)                250
# Min Temp Flag                  8
# Mean Temp (°C)               250
# Mean Temp Flag                 8
# Heat Deg Days (°C)           250
# Heat Deg Days Flag             8
# Cool Deg Days (°C)           250
# Cool Deg Days Flag             8
# Total Rain (mm)              256
# Total Rain Flag               21
# Total Snow (cm)              256
# Total Snow Flag               31
# Total Precip (mm)            257
# ...

# %% [markdown]
# ### only use next cel to rebuild

# %%
# weatherDF=tempweather17
# weatherDF=weatherDF.append(tempweather18,ignore_index=True)
# weatherDF=weatherDF.append(tempweather19,ignore_index=True)
# weatherDF=weatherDF.append(tempweather20,ignore_index=True)

# print(weatherDF.head())
# print(weatherDF.tail())

# %%
weatherDF = pd.read_pickle("./AllWeather.pkl")

print('\nbefore append ',weatherDF.count())

# weatherDF.append(tempweather18)

weatherDF = weatherDF.append(tempweather20,ignore_index=True)
print('\nRows before drop dups ',weatherDF.count())
print(weatherDF.head())
print(weatherDF.tail())
# Out:
# before append  Longitude (x)                1461
# Latitude (y)                 1461
# Station Name                 1461
# Climate ID                   1461
# Date/Time                    1461
# Year                         1461
# Month                        1461
# Day                          1461
# Data Quality                    0
# Max Temp (°C)                1331
# Max Temp Flag                  49
# Min Temp (°C)                1312
# Min Temp Flag                  49
# Mean Temp (°C)               1309
# Mean Temp Flag                 49
# Heat Deg Days (°C)           1309
# Heat Deg Days Flag             49
# Cool Deg Days (°C)           1309
# Cool Deg Days Flag             49
# Total Rain (mm)              1293
# Total Rain Flag               130
# Total Snow (cm)              1317
# Total Snow Flag               138
# Total Precip (mm)            1345
# Total Precip Flag             180
# Snow on Grnd (cm)             587
# Snow on Grnd Flag             127
# ...

# %%
weatherDF = weatherDF.drop_duplicates(keep='last',subset=['Date/Time','Year','Month','Day'])
print(weatherDF.count(),'\n\n\n')

weatherDF.sort_values('Date/Time')

print(weatherDF.head())
print(weatherDF.tail())
# Out:
# Longitude (x)                1461
# Latitude (y)                 1461
# Station Name                 1461
# Climate ID                   1461
# Date/Time                    1461
# Year                         1461
# Month                        1461
# Day                          1461
# Data Quality                    0
# Max Temp (°C)                1333
# Max Temp Flag                  49
# Min Temp (°C)                1314
# Min Temp Flag                  49
# Mean Temp (°C)               1311
# Mean Temp Flag                 49
# Heat Deg Days (°C)           1311
# Heat Deg Days Flag             49
# Cool Deg Days (°C)           1311
# Cool Deg Days Flag             49
# Total Rain (mm)              1295
# Total Rain Flag               131
# Total Snow (cm)              1319
# Total Snow Flag               138
# Total Precip (mm)            1347
# Total Precip Flag             181
# Snow on Grnd (cm)             587
# Snow on Grnd Flag             127
# ...

# %%
weatherDF = weatherDF.sort_values('Date/Time')

# print(weatherDF.head())
# print(weatherDF.tail())

# %%
# print(weatherDF[360:370],'\n\n\n')
# print(weatherDF[720:740],'\n\n\n')
print(weatherDF[1250:1350],'\n\n\n')
# Out:
#       Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time  \
# 1616        -114.01         51.12  CALGARY INTL A     3031092  2020-06-04
# 1617        -114.01         51.12  CALGARY INTL A     3031092  2020-06-05
# 1618        -114.01         51.12  CALGARY INTL A     3031092  2020-06-06
# 1619        -114.01         51.12  CALGARY INTL A     3031092  2020-06-07
# 1620        -114.01         51.12  CALGARY INTL A     3031092  2020-06-08
# ...             ...           ...             ...         ...         ...
# 1711        -114.01         51.12  CALGARY INTL A     3031092  2020-09-07
# 1712        -114.01         51.12  CALGARY INTL A     3031092  2020-09-08
# 1713        -114.01         51.12  CALGARY INTL A     3031092  2020-09-09
# 1714        -114.01         51.12  CALGARY INTL A     3031092  2020-09-10
# 1715        -114.01         51.12  CALGARY INTL A     3031092  2020-09-11
#
#       Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# ...

# %%
import datetime
#weatherDF['Day of Year'] = 

#print(weatherDF['Date/Time'])
#print(pd.Period(pd.to_datetime(weatherDF['Date/Time'], infer_datetime_format=True), freq='D'))
weatherDF['DT_dateTime']=pd.to_datetime(weatherDF['Date/Time'], infer_datetime_format=True)

weatherDF['DayOfYear']=weatherDF['DT_dateTime'].dt.dayofyear
weatherDF
# Out:
#       Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time  \
# 0           -114.01         51.12  CALGARY INTL A     3031092  2017-01-01
# 1           -114.01         51.12  CALGARY INTL A     3031092  2017-01-02
# 2           -114.01         51.12  CALGARY INTL A     3031092  2017-01-03
# 3           -114.01         51.12  CALGARY INTL A     3031092  2017-01-04
# 4           -114.01         51.12  CALGARY INTL A     3031092  2017-01-05
# ...             ...           ...             ...         ...         ...
# 1822        -114.01         51.12  CALGARY INTL A     3031092  2020-12-27
# 1823        -114.01         51.12  CALGARY INTL A     3031092  2020-12-28
# 1824        -114.01         51.12  CALGARY INTL A     3031092  2020-12-29
# 1825        -114.01         51.12  CALGARY INTL A     3031092  2020-12-30
# 1826        -114.01         51.12  CALGARY INTL A     3031092  2020-12-31
#
#       Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Precip (mm)  \
# ...

# %%
weatherDF.to_csv("./weather.csv")
weatherDF.to_pickle("./AllWeather.pkl")

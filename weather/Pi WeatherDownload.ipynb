# %%
# Command line:  

# for year in `seq 1998 2008`;do for month in `seq 1 12`;do wget --content-disposition "http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=1706&Year=${year}&Month=${month}&Day=14&timeframe=1&submit= Download+Data" ;done;done


# WHERE; 
# • year = change values in command line (`seq 1998 2008)
# • month = change values in command line (`seq 1 12)
# • format= [csv|xml]: the format output
# • timeframe = 1: for hourly data 
# • timeframe = 2: for daily data 
# • timeframe = 3 for monthly data 
# • Day: the value of the "day" variable is not used and can be an arbitrary value 
# • For another station, change the value of the variable stationID
# • For the data in XML format, change the value of the variable format to xml in the URL. 

import urllib.request

req = urllib.request.Request('http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2017&Month=5&Day=17&timeframe=2&submit=Download+Data')
with urllib.request.urlopen(req) as response:
   the_page = response.read()

print(the_page.decode())
# Out:
# ﻿"Station Name","CALGARY INTL A"
# "Province","ALBERTA"
# "Latitude","51.12"
# "Longitude","-114.01"
# "Elevation","1099.10"
# "Climate Identifier","3031092"
# "WMO Identifier","71877"
# "TC Identifier","YYC"
#
# "Legend"
# "A","Accumulated"
# "C","Precipitation occurred, amount uncertain"
# "E","Estimated"
# "F","Accumulated and estimated"
# "L","Precipitation may or may not have occurred"
# "M","Missing"
# "N","Temperature missing but known to be > 0"
# "S","More than one occurrence"
# "T","Trace"
# "Y","Temperature missing but known to be < 0"
# "[empty]","No data available"
# "^","The value displayed is based on incomplete data"
# "†","Data that is not subject to review by the National Climate Archives"
#
# ...

# %%
import pandas as pd

# weatherDF=pd.DataFrame()

# weatherDF.info
url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2017&Month=5&Day=19&timeframe=2&submit=Download+Data"
print(url)
tempweather=pd.read_csv(url,skiprows=24)
# print(c)
print(tempweather.head())
#     url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year="+str(x)+"&Month=5&Day=19&timeframe=2&submit=Download+Data"
#     print(url)
#     c=pd.read_csv(url,skiprows=25)
#     weatherDF.append(c,ignore_index=True) 
# #     print("this is c ",c)

# print('the appended ',weatherDF)
# Out:
# http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2017&Month=5&Day=19&timeframe=2&submit=Download+Data
#     Date/Time  Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# 0  2017-01-01  2017      1    1           NaN           -7.8           NaN
# 1  2017-01-02  2017      1    2           NaN          -16.1           NaN
# 2  2017-01-03  2017      1    3           NaN          -15.5           NaN
# 3  2017-01-04  2017      1    4           NaN           -7.2           NaN
# 4  2017-01-05  2017      1    5           NaN           -3.5           NaN
#
#    Min Temp (°C) Min Temp Flag  Mean Temp (°C)          ...           \
# 0          -17.4           NaN           -12.6          ...
# 1          -26.1           NaN           -21.1          ...
# 2          -22.4           NaN           -19.0          ...
# 3          -17.2           NaN           -12.2          ...
# 4          -15.8           NaN            -9.7          ...
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: []
# Index: []>

# %%
import pandas as pd

weatherDF=pd.DataFrame()

weatherDF.info
url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2017&Month=5&Day=19&timeframe=2&submit=Download+Data"
print(url)
tempweather17=pd.read_csv(url,skiprows=24)
print(tempweather17.head())

url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2018&Month=5&Day=19&timeframe=2&submit=Download+Data"
print(url)
tempweather18=pd.read_csv(url,skiprows=25)
print(tempweather18.head())

url="http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2019&Month=5&Day=19&timeframe=2&submit=Download+Data"
print(url)
tempweather19=pd.read_csv(url,skiprows=25)
print(tempweather19.head())



# weatherDF.append(tempweather,ignore_index=True)
# Out:
# http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=50430&Year=2017&Month=5&Day=19&timeframe=2&submit=Download+Data
#     Date/Time  Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# 0  2017-01-01  2017      1    1           NaN           -7.8           NaN
# 1  2017-01-02  2017      1    2           NaN          -16.1           NaN
# 2  2017-01-03  2017      1    3           NaN          -15.5           NaN
# 3  2017-01-04  2017      1    4           NaN           -7.2           NaN
# 4  2017-01-05  2017      1    5           NaN           -3.5           NaN
#
#    Min Temp (°C) Min Temp Flag  Mean Temp (°C)          ...           \
# 0          -17.4           NaN           -12.6          ...
# 1          -26.1           NaN           -21.1          ...
# 2          -22.4           NaN           -19.0          ...
# 3          -17.2           NaN           -12.2          ...
# 4          -15.8           NaN            -9.7          ...
#
# ...

# %%
weatherDF = tempweather17
weatherDF.append(tempweather18,ignore_index=True)
weatherDF.append(tempweather19,ignore_index=True)
print(weatherDF.head())
print(weatherDF.tail())
# Out:
#     Date/Time  Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# 0  2017-01-01  2017      1    1           NaN           -7.8           NaN
# 1  2017-01-02  2017      1    2           NaN          -16.1           NaN
# 2  2017-01-03  2017      1    3           NaN          -15.5           NaN
# 3  2017-01-04  2017      1    4           NaN           -7.2           NaN
# 4  2017-01-05  2017      1    5           NaN           -3.5           NaN
#
#    Min Temp (°C) Min Temp Flag  Mean Temp (°C)          ...           \
# 0          -17.4           NaN           -12.6          ...
# 1          -26.1           NaN           -21.1          ...
# 2          -22.4           NaN           -19.0          ...
# 3          -17.2           NaN           -12.2          ...
# 4          -15.8           NaN            -9.7          ...
#
#   Total Snow (cm)  Total Snow Flag Total Precip (mm)  Total Precip Flag  \
# ...

# %%
weatherDF.to_pickle("./AllWeather.pkl")
weatherDF.head()
# Out:
#     Date/Time  Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# 0  2017-01-01  2017      1    1           NaN           -7.8           NaN
# 1  2017-01-02  2017      1    2           NaN          -16.1           NaN
# 2  2017-01-03  2017      1    3           NaN          -15.5           NaN
# 3  2017-01-04  2017      1    4           NaN           -7.2           NaN
# 4  2017-01-05  2017      1    5           NaN           -3.5           NaN
#
#    Min Temp (°C) Min Temp Flag  Mean Temp (°C)          ...           \
# 0          -17.4           NaN           -12.6          ...
# 1          -26.1           NaN           -21.1          ...
# 2          -22.4           NaN           -19.0          ...
# 3          -17.2           NaN           -12.2          ...
# 4          -15.8           NaN            -9.7          ...
#
#   Total Snow (cm)  Total Snow Flag Total Precip (mm)  Total Precip Flag  \
# ...

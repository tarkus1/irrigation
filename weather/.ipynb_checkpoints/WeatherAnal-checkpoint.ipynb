# %%
import pandas as pd

weatherDF = pd.read_pickle("./AllWeather.pkl")

# %%
weatherDF.tail(190)
# Out:
#       Date/Time  Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# 175  2019-06-25  2019      6   25           NaN            NaN           NaN
# 176  2019-06-26  2019      6   26           NaN            NaN           NaN
# 177  2019-06-27  2019      6   27           NaN            NaN           NaN
# 178  2019-06-28  2019      6   28           NaN            NaN           NaN
# 179  2019-06-29  2019      6   29           NaN            NaN           NaN
# 180  2019-06-30  2019      6   30           NaN            NaN           NaN
# 181  2019-07-01  2019      7    1           NaN            NaN           NaN
# 182  2019-07-02  2019      7    2           NaN            NaN           NaN
# 183  2019-07-03  2019      7    3           NaN            NaN           NaN
# 184  2019-07-04  2019      7    4           NaN            NaN           NaN
# 185  2019-07-05  2019      7    5           NaN            NaN           NaN
# ...

# %%
import feedparser
d = feedparser.parse('https://weather.gc.ca/rss/city/ab-52_e.xml')
print(d.feed.title)
len(d['items'])
# Out:
# Calgary - Weather - Environment Canada
# 14

# %%
d
# Out:
# {'feed': {'language': 'en-ca',
#   'title': 'Calgary - Weather - Environment Canada',
#   'title_detail': {'type': 'text/plain',
#    'language': 'en-ca',
#    'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#    'value': 'Calgary - Weather - Environment Canada'},
#   'links': [{'rel': 'related',
#     'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#     'type': 'text/html'},
#    {'rel': 'self',
#     'href': 'https://www.weather.gc.ca/rss/city/ab-52_e.xml',
#     'type': 'application/atom+xml'},
#    {'rel': 'alternate',
#     'hreflang': 'fr-ca',
#     'href': 'https://www.meteo.gc.ca/rss/city/ab-52_f.xml',
#     'type': 'application/atom+xml'}],
#   'authors': [{'name': 'Environment Canada',
#     'href': 'https://www.weather.gc.ca'}],
#   'author_detail': {'name': 'Environment Canada',
#    'href': 'https://www.weather.gc.ca'},
#   'href': 'https://www.weather.gc.ca',
#   'author': 'Environment Canada',
#   'updated': '2019-06-01T03:20:17Z',
# ...

# %%
for i in range(0,14):
    e = d['items'][i]
    print(e['title'],"\n")
#     print(e['link'])
#     print(e['description'],"\n")
# Out:
# SPECIAL AIR QUALITY STATEMENT , Calgary
#
# Current Conditions: Mostly Cloudy, 18.0°C
#
# Friday night: Chance of showers. Low 11. POP 60%
#
# Saturday: Mainly sunny. High 28.
#
# Saturday night: A few clouds. Low 14.
#
# Sunday: Sunny. High 29.
#
# Sunday night: Clear. Low 17.
#
# Monday: Sunny. High 26.
#
# Monday night: Clear. Low 10.
#
# Tuesday: Sunny. High 23.
#
# Tuesday night: Cloudy periods. Low 8.
#
# Wednesday: A mix of sun and cloud. High 18.
#
# Wednesday night: Chance of showers. Low 6. POP 60%
#
# Thursday: A mix of sun and cloud. High 17.

# %%
import pandas as pd
import feedparser

d = feedparser.parse('https://weather.gc.ca/rss/city/ab-52_e.xml')
print(d.feed.title)
len(d['items'])
# Out:
# Calgary - Weather - Environment Canada
# 14

# %%
d
# Out:
# {'feed': {'language': 'en-ca',
#   'title': 'Calgary - Weather - Environment Canada',
#   'title_detail': {'type': 'text/plain',
#    'language': 'en-ca',
#    'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#    'value': 'Calgary - Weather - Environment Canada'},
#   'links': [{'rel': 'related',
#     'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#     'type': 'text/html'},
#    {'rel': 'self',
#     'href': 'https://www.weather.gc.ca/rss/city/ab-52_e.xml',
#     'type': 'application/atom+xml'},
#    {'rel': 'alternate',
#     'hreflang': 'fr-ca',
#     'href': 'https://www.meteo.gc.ca/rss/city/ab-52_f.xml',
#     'type': 'application/atom+xml'}],
#   'authors': [{'name': 'Environment Canada',
#     'href': 'https://www.weather.gc.ca'}],
#   'author_detail': {'name': 'Environment Canada',
#    'href': 'https://www.weather.gc.ca'},
#   'href': 'https://www.weather.gc.ca',
#   'author': 'Environment Canada',
#   'updated': '2019-06-23T21:50:05Z',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=21, tm_min=50, tm_sec=5, tm_wday=6, tm_yday=174, tm_isdst=0),
#   'id': 'tag:weather.gc.ca,2013-04-16:20190623215005',
#   'guidislink': True,
#   'link': 'tag:weather.gc.ca,2013-04-16:20190623215005',
#   'logo': 'https://www.weather.gc.ca/template/gcweb/v4.0.24/assets/wmms-alt.png',
#   'icon': 'https://www.weather.gc.ca/template/gcweb/v4.0.24/assets/favicon.ico',
#   'rights': 'Copyright 2019, Environment Canada',
#   'rights_detail': {'type': 'text/plain',
#    'language': 'en-ca',
#    'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#    'value': 'Copyright 2019, Environment Canada'}},
#  'entries': [{'title': 'No watches or warnings in effect, Calgary',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'No watches or warnings in effect, Calgary'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/warnings/index_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/warnings/index_e.html',
#    'updated': '2019-06-21T22:15:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=21, tm_hour=22, tm_min=15, tm_sec=0, tm_wday=4, tm_yday=172, tm_isdst=0),
#    'published': '2019-06-21T22:15:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=21, tm_hour=22, tm_min=15, tm_sec=0, tm_wday=4, tm_yday=172, tm_isdst=0),
#    'tags': [{'term': 'Warnings and Watches', 'scheme': None, 'label': None}],
#    'summary': 'No watches or warnings in effect.',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'No watches or warnings in effect.'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_w1:20190621221500',
#    'guidislink': False},
#   {'title': 'Current Conditions: Mostly Cloudy, 16.8°C',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Current Conditions: Mostly Cloudy, 16.8°C'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T21:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T21:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Current Conditions', 'scheme': None, 'label': None}],
#    'summary': "<b>Observed at:</b> Calgary Int'l Airport 3:00 PM MDT Sunday 23 June 2019 <br/>\n<b>Condition:</b> Mostly Cloudy <br/>\n<b>Temperature:</b> 16.8&deg;C <br/>\n<b>Pressure / Tendency:</b> 101.0 kPa falling<br/>\n<b>Visibility:</b> 24.1 km<br/>\n<b>Humidity:</b> 57 %<br/>\n<b>Dewpoint:</b> 8.4&deg;C <br/>\n<b>Wind:</b> NW 15 km/h<br/>\n<b>Air Quality Health Index:</b> 2 <br/>",
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': "<b>Observed at:</b> Calgary Int'l Airport 3:00 PM MDT Sunday 23 June 2019 <br/>\n<b>Condition:</b> Mostly Cloudy <br/>\n<b>Temperature:</b> 16.8&deg;C <br/>\n<b>Pressure / Tendency:</b> 101.0 kPa falling<br/>\n<b>Visibility:</b> 24.1 km<br/>\n<b>Humidity:</b> 57 %<br/>\n<b>Dewpoint:</b> 8.4&deg;C <br/>\n<b>Wind:</b> NW 15 km/h<br/>\n<b>Air Quality Health Index:</b> 2 <br/>"},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_cc:20190623210000',
#    'guidislink': False},
#   {'title': 'Sunday night: Chance of showers. Low 8. POP 60%',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Sunday night: Chance of showers. Low 8. POP 60%'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Partly cloudy. 60 percent chance of showers this evening with risk of a thunderstorm. Wind northwest 20 km/h becoming light this evening. Low 8. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Partly cloudy. 60 percent chance of showers this evening with risk of a thunderstorm. Wind northwest 20 km/h becoming light this evening. Low 8. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc1:20190623220000',
#    'guidislink': False},
#   {'title': 'Monday: Chance of showers. High 17. POP 60%',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Monday: Chance of showers. High 17. POP 60%'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'A mix of sun and cloud. 60 percent chance of showers in the afternoon with risk of a thunderstorm. Wind becoming north 20 km/h in the afternoon. High 17. UV index 8 or very high. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'A mix of sun and cloud. 60 percent chance of showers in the afternoon with risk of a thunderstorm. Wind becoming north 20 km/h in the afternoon. High 17. UV index 8 or very high. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc2:20190623220000',
#    'guidislink': False},
#   {'title': 'Monday night: Chance of showers. Low 8. POP 60%',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Monday night: Chance of showers. Low 8. POP 60%'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Partly cloudy. 60 percent chance of showers in the evening with risk of a thunderstorm. Wind north 20 km/h becoming light in the evening. Low 8. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Partly cloudy. 60 percent chance of showers in the evening with risk of a thunderstorm. Wind north 20 km/h becoming light in the evening. Low 8. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc3:20190623220000',
#    'guidislink': False},
#   {'title': 'Tuesday: Chance of showers. High 16. POP 30%',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Tuesday: Chance of showers. High 16. POP 30%'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'A mix of sun and cloud with 30 percent chance of showers. High 16. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'A mix of sun and cloud with 30 percent chance of showers. High 16. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc4:20190623220000',
#    'guidislink': False},
#   {'title': 'Tuesday night: Chance of showers. Low 8. POP 30%',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Tuesday night: Chance of showers. Low 8. POP 30%'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Cloudy periods with 30 percent chance of showers. Low 8. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Cloudy periods with 30 percent chance of showers. Low 8. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc5:20190623220000',
#    'guidislink': False},
#   {'title': 'Wednesday: Sunny. High 20.',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Wednesday: Sunny. High 20.'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Sunny. High 20. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Sunny. High 20. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc6:20190623220000',
#    'guidislink': False},
#   {'title': 'Wednesday night: Cloudy periods. Low 10.',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Wednesday night: Cloudy periods. Low 10.'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Increasing cloudiness. Low 10. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Increasing cloudiness. Low 10. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc7:20190623220000',
#    'guidislink': False},
#   {'title': 'Thursday: Showers. High 17.',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Thursday: Showers. High 17.'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Showers. High 17. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Showers. High 17. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc8:20190623220000',
#    'guidislink': False},
#   {'title': 'Thursday night: Showers. Low 10.',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Thursday night: Showers. Low 10.'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Showers. Low 10. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Showers. Low 10. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc9:20190623220000',
#    'guidislink': False},
#   {'title': 'Friday: Chance of showers. High 19. POP 60%',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Friday: Chance of showers. High 19. POP 60%'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Cloudy with 60 percent chance of showers. High 19. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Cloudy with 60 percent chance of showers. High 19. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc10:20190623220000',
#    'guidislink': False},
#   {'title': 'Friday night: Chance of showers. Low 10. POP 60%',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Friday night: Chance of showers. Low 10. POP 60%'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Cloudy periods with 60 percent chance of showers. Low 10. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Cloudy periods with 60 percent chance of showers. Low 10. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc11:20190623220000',
#    'guidislink': False},
#   {'title': 'Saturday: Sunny. High 21.',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Saturday: Sunny. High 21.'},
#    'links': [{'type': 'text/html',
#      'href': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#      'rel': 'alternate'}],
#    'link': 'https://www.weather.gc.ca/city/pages/ab-52_metric_e.html',
#    'updated': '2019-06-23T22:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'published': '2019-06-23T22:00:00Z',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=174, tm_isdst=0),
#    'tags': [{'term': 'Weather Forecasts', 'scheme': None, 'label': None}],
#    'summary': 'Sunny. High 21. Forecast issued 4:00 PM MDT Sunday 23 June 2019',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en-ca',
#     'base': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#     'value': 'Sunny. High 21. Forecast issued 4:00 PM MDT Sunday 23 June 2019'},
#    'id': 'tag:weather.gc.ca,2013-04-16:ab-52_fc12:20190623220000',
#    'guidislink': False}],
#  'bozo': 0,
#  'headers': {'Date': 'Sun, 23 Jun 2019 21:56:15 GMT',
#   'Server': 'Apache',
#   'Last-Modified': 'Sun, 23 Jun 2019 21:50:05 GMT',
#   'ETag': '"2092-58c04adad32ae-gzip"',
#   'Accept-Ranges': 'bytes',
#   'Vary': 'Accept-Encoding',
#   'Content-Encoding': 'gzip',
#   'X-UA-Compatible': 'IE=Edge',
#   'Content-Length': '1464',
#   'Connection': 'close',
#   'Content-Type': 'application/xml'},
#  'etag': '"2092-58c04adad32ae-gzip"',
#  'updated': 'Sun, 23 Jun 2019 21:50:05 GMT',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=23, tm_hour=21, tm_min=50, tm_sec=5, tm_wday=6, tm_yday=174, tm_isdst=0),
#  'href': 'https://weather.gc.ca/rss/city/ab-52_e.xml',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'atom10',
#  'namespaces': {'': 'http://www.w3.org/2005/Atom'}}

# %%
popDF =  pd.DataFrame(columns=['Day', 'DayNight', 'POP'])

for i in range(0,14):
    e = d['items'][i]
    print("\nNew Day ", e['title'],"\n")
    fcst=e['title'].split(':')
    print(len(fcst),'\n')
            
    
    dayNight = fcst[0].split(' ')
    
    print(len(dayNight))
    
    theDay = dayNight[0]
    if len(dayNight)>1:
        if (dayNight[1] == 'night'):
            timeofDay = 'night'
    else:
        timeofDay = 'day'
    
    print(theDay, timeofDay)
    
    if len(fcst)>1:
        print('second part ',fcst[1])
        if fcst[1].find('POP') > 0:
            pop = fcst[1].split('POP')
            print('\nPOP ',pop[1])
            popDF = popDF.append({'Day': theDay, 'DayNight': timeofDay, 'POP': pop[1]}, ignore_index=True)

        
print('\nPOP days\n',popDF)

#     print(e['link'])
#     print(e['description'],"\n")
# Out:
# New Day  No watches or warnings in effect, Calgary
#
# 1
#
# 7
# No day
#
# New Day  Current Conditions: Mainly Clear, 16.1°C
#
# 2
#
# 2
# Current day
# second part   Mainly Clear, 16.1°C
#
# New Day  Friday night: A few clouds. Low 8.
#
# 2
#
# 2
# Friday night
# second part   A few clouds. Low 8.
#
# New Day  Saturday: Mainly sunny. High 20.
#
# 2
#
# 1
# Saturday day
# second part   Mainly sunny. High 20.
#
# New Day  Saturday night: A few clouds. Low 9.
#
# 2
#
# 2
# Saturday night
# second part   A few clouds. Low 9.
#
# New Day  Sunday: Sunny. High 22.
#
# 2
#
# 1
# Sunday day
# second part   Sunny. High 22.
#
# New Day  Sunday night: Clear. Low 11.
#
# 2
#
# 2
# Sunday night
# second part   Clear. Low 11.
#
# New Day  Monday: Chance of showers. High 24. POP 30%
#
# 2
#
# 1
# Monday day
# second part   Chance of showers. High 24. POP 30%
#
# POP   30%
#
# New Day  Monday night: Chance of showers. Low 6. POP 60%
#
# 2
#
# 2
# Monday night
# second part   Chance of showers. Low 6. POP 60%
#
# POP   60%
#
# New Day  Tuesday: Chance of showers. High 14. POP 60%
#
# 2
#
# 1
# Tuesday day
# second part   Chance of showers. High 14. POP 60%
#
# POP   60%
#
# New Day  Tuesday night: Chance of showers. Low 8. POP 60%
#
# 2
#
# 2
# Tuesday night
# second part   Chance of showers. Low 8. POP 60%
#
# POP   60%
#
# New Day  Wednesday: Chance of showers. High 18. POP 30%
#
# 2
#
# 1
# Wednesday day
# second part   Chance of showers. High 18. POP 30%
#
# POP   30%
#
# New Day  Wednesday night: Chance of showers. Low 9. POP 30%
#
# 2
#
# 2
# Wednesday night
# second part   Chance of showers. Low 9. POP 30%
#
# POP   30%
#
# New Day  Thursday: Chance of showers. High 19. POP 60%
#
# 2
#
# 1
# Thursday day
# second part   Chance of showers. High 19. POP 60%
#
# POP   60%
#
# POP days
#           Day DayNight   POP
# 0     Monday      day   30%
# 1     Monday    night   60%
# 2    Tuesday      day   60%
# 3    Tuesday    night   60%
# 4  Wednesday      day   30%
# 5  Wednesday    night   30%
# 6   Thursday      day   60%

# %%
from datetime import *
[datetime.today()+timedelta(days=x) for x in range(0,7) if (datetime.today()+timedelta(days=x)).weekday() % 7 == 1]

# (0 at the end is for next monday, returns current date when run on monday)
# Out:
# [datetime.datetime(2019, 7, 2, 22, 1, 11, 490136)]

# %%
from datetime import timedelta
def get_next_monday():
    date0 = datetime.now()
#     date0 = datetime.date(year, month, day)
    next_monday = date0 + timedelta(7 - date0.weekday() or 7)
    return next_monday

print (get_next_monday())
# Out:
# 2019-07-01 22:01:19.794266

# %%
import calendar
import pandas as pd

fcstDays = pd.DataFrame(columns=['Day', 'Date'])

for dd in range(0,14):
    
    dayN = datetime.now() + timedelta(days=dd)
    dayName = calendar.day_name[dayN.weekday()]
    dayDt = dayN.date()
    
    fcstDays = fcstDays.append({'Day': dayName, 'Date': dayDt}, ignore_index=True)

fcstDays
# Out:
#           Day        Date
# 0      Friday  2019-06-28
# 1    Saturday  2019-06-29
# 2      Sunday  2019-06-30
# 3      Monday  2019-07-01
# 4     Tuesday  2019-07-02
# 5   Wednesday  2019-07-03
# 6    Thursday  2019-07-04
# 7      Friday  2019-07-05
# 8    Saturday  2019-07-06
# 9      Sunday  2019-07-07
# 10     Monday  2019-07-08
# 11    Tuesday  2019-07-09
# 12  Wednesday  2019-07-10
# 13   Thursday  2019-07-11

# %%
print(fcstDays.loc[fcstDays['Day'] == 'Monday'].Date[8])
# Out:
# 2019-07-01

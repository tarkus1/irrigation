# %%
import pandas as pd

weatherDF = pd.read_pickle("./AllWeather.pkl")

# %%
weatherDF.tail(190)
# Out:
#       Date/Time  Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# 564  2019-06-27  2019      6   27           NaN            NaN           NaN
# 563  2019-06-27  2019      6   27           NaN           16.2           NaN
# 565  2019-06-28  2019      6   28           NaN           21.9           NaN
# 566  2019-06-28  2019      6   28           NaN            NaN           NaN
# 567  2019-06-29  2019      6   29           NaN            NaN           NaN
# 568  2019-06-30  2019      6   30           NaN            NaN           NaN
# 569  2019-07-01  2019      7    1           NaN            NaN           NaN
# 570  2019-07-02  2019      7    2           NaN            NaN           NaN
# 571  2019-07-03  2019      7    3           NaN            NaN           NaN
# 572  2019-07-04  2019      7    4           NaN            NaN           NaN
# 573  2019-07-05  2019      7    5           NaN            NaN           NaN
# ...

# %% [markdown]
# # can start analysis!

# %%
import pandas as pd
import logging
from datetime import datetime
import dateutil
from pytz import timezone


weatherDF = pd.read_pickle("./AllWeather.pkl")
# print(weatherDF['Date/Time','Total Rain (mm)'][540:720])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Date/Time', 'Total Rain (mm)')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-e89ee9ed8eab> in <module>
#       7
#       8 weatherDF = pd.read_pickle("./AllWeather.pkl")
# ----> 9 print(weatherDF['Date/Time','Total Rain (mm)'][540:720])
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Date/Time', 'Total Rain (mm)')

# %%
weatherDF['Date/Time'] = pd.to_datetime(weatherDF['Date/Time'])
moistHist = weatherDF[['Date/Time','Total Rain (mm)','Max Temp (°C)','Min Temp (°C)','Mean Temp (°C)']]
moistHist[moistHist['Total Rain (mm)'] > 0]
# Out:
#       Date/Time  Total Rain (mm)  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)
# 2    2017-01-03              0.1          -15.5          -22.4           -19.0
# 30   2017-01-31              0.2           -4.6          -12.1            -8.4
# 31   2017-02-01              0.2           -7.1          -11.8            -9.5
# 55   2017-02-25              0.2           -3.1          -10.5            -6.8
# 76   2017-03-18              0.6           15.4           -3.5             6.0
# ...         ...              ...            ...            ...             ...
# 1241 2020-05-26              2.0           15.3            6.0            10.7
# 1246 2020-05-31             41.0           19.6           10.4            15.0
# 1251 2020-06-05              1.8           18.6            4.0            11.3
# 1252 2020-06-06              3.6           19.1            9.4            14.3
# 1253 2020-06-07              9.7           11.6            7.8             9.7
#
# [233 rows x 5 columns]

# %%
# from datetime 
# import Period
weatherDF['Day of Year'] = weatherDF.to_period(['Date/Time'], freq='D', axis=1, copy=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-61942d5f2fc1> in <module>
#       1 # from datetime
#       2 # import Period
# ----> 3 weatherDF['Day of Year'] = weatherDF.to_period(['Date/Time'], freq='D', axis=1, copy=True)
#
# TypeError: to_period() got multiple values for argument 'freq'

# %%
fcstHist = pd.read_pickle('/home/mark/Documents/irrigation/weather/FcstHistory.pkl')
fcstHist
# Out:
#          Day DayNight   POP             Forecast Date Date Forecasted
# 0     Sunday    night   30% 2019-06-30 16:00:00-06:00      2019-06-30
# 1     Monday    night   60% 2019-06-30 16:00:00-06:00      2019-07-01
# 2  Wednesday    night   60% 2019-06-30 16:00:00-06:00      2019-07-03
# 3   Thursday    night   60% 2019-06-30 16:00:00-06:00      2019-07-04
# 4     Friday      day   60% 2019-06-30 16:00:00-06:00      2019-07-05
# 5     Friday    night   60% 2019-06-30 16:00:00-06:00      2019-07-05
# 6   Saturday      day   60% 2019-06-30 16:00:00-06:00      2019-07-06

# %% [markdown]
# # can start analysis!

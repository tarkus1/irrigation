# %%
import pandas as pd
import logging
from datetime import datetime
import dateutil
from pytz import timezone


weatherDF = pd.read_pickle("./AllWeather.pkl")

# %%
weatherDF['Date/Time'] = pd.to_datetime(weatherDF['Date/Time'])
moistHist = weatherDF[['Date/Time','Total Rain (mm)','Max Temp (°C)','Min Temp (°C)','Mean Temp (°C)']]
moistHist[moistHist['Total Rain (mm)'] > 0]
# Out:
#      Date/Time  Total Rain (mm)  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)
# 86  2018-03-28              1.3            2.7           -2.7             0.0
# 94  2018-04-05              0.2           -5.8          -13.4            -9.6
# 101 2018-04-12              1.2           -1.7           -3.8            -2.8
# 118 2018-04-29              6.0           18.4            2.1            10.3
# 119 2018-04-30              0.8           14.6            1.7             8.2
# 120 2018-05-01              0.4           13.2            5.5             9.4
# 128 2018-05-09              1.7           14.1            4.7             9.4
# 129 2018-05-10              2.6           10.0            2.5             6.3
# 130 2018-05-11              0.2           16.4            3.3             9.9
# 136 2018-05-17             10.8           12.5            6.1             9.3
# 137 2018-05-18              1.8           14.4            5.7            10.1
# ...

# %%
moistHist.dtypes
# Out:
# Date/Time          datetime64[ns]
# Total Rain (mm)           float64
# Max Temp (°C)             float64
# Min Temp (°C)             float64
# Mean Temp (°C)            float64
# dtype: object

# %% [markdown]
# # can start analysis!

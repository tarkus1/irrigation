# %%
import pandas as pd

weatherDF = pd.read_pickle("./AllWeather.pkl")

# %%
weatherDF.tail()
# Out:
#       Date/Time  Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# 360  2017-12-27  2017     12   27           NaN          -18.4           NaN
# 361  2017-12-28  2017     12   28           NaN          -16.4           NaN
# 362  2017-12-29  2017     12   29           NaN          -21.3           NaN
# 363  2017-12-30  2017     12   30           NaN          -25.2           NaN
# 364  2017-12-31  2017     12   31           NaN          -25.0           NaN
#
#      Min Temp (°C) Min Temp Flag  Mean Temp (°C)          ...           \
# 360          -25.5           NaN           -22.0          ...
# 361          -28.2           NaN           -22.3          ...
# 362          -25.4           NaN           -23.4          ...
# 363          -28.7           NaN           -27.0          ...
# 364          -31.3           NaN           -28.2          ...
#
#     Total Snow (cm)  Total Snow Flag Total Precip (mm)  Total Precip Flag  \
# ...

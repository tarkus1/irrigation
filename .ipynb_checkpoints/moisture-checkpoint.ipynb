# %%
import pandas as pd

# moist = pd.read_csv('/home/pi/irrigation/test.csv')
moist = pd.read_csv('test.csv')

# %%
moist.columns = ["Timetemp", "Humidity", "Temp"]
moist.tail()
# Out:
#                Timetemp  Humidity     Temp
# 5365  20190528 11:19:36   39.3750  30.2761
# 5366  20190528 11:20:50   40.0938  30.3841
# 5367  20190528 11:22:21   40.5938  30.4181
# 5368  20190528 11:24:05   40.4375  30.3841
# 5369  20190528 11:26:02   39.8438  30.3672

# %%
moist['Time'] = pd.to_datetime(moist["Timetemp"])
moist = moist.drop(columns='Timetemp')
moist.dtypes
# Out:
# Humidity           float64
# Temp               float64
# Time        datetime64[ns]
# dtype: object

# %%
# import datetime

d = datetime.datetime(2008, 8, 18, 9, 0)
d + pd.offsets.Week(-1)

moist['WeekAgo'] = moist['Time'] +pd.offsets.Week(-1)

moist.head()
# Out:
#    Humidity     Temp                Time             WeekAgo
# 0   19.2812  25.5513 2019-05-24 16:19:41 2019-05-10 16:19:41
# 1   19.3750  25.5064 2019-05-24 16:20:42 2019-05-10 16:20:42
# 2   19.5000  25.8244 2019-05-24 16:21:43 2019-05-10 16:21:43
# 3   19.7188  25.8364 2019-05-24 16:22:44 2019-05-10 16:22:44
# 4   19.5625  25.8278 2019-05-24 16:23:44 2019-05-10 16:23:44

# %%
moist = moist.set_index('Time')
moist.head()
# Out:
#                      Humidity     Temp             WeekAgo
# Time
# 2019-05-24 16:19:41   19.2812  25.5513 2019-05-10 16:19:41
# 2019-05-24 16:20:42   19.3750  25.5064 2019-05-10 16:20:42
# 2019-05-24 16:21:43   19.5000  25.8244 2019-05-10 16:21:43
# 2019-05-24 16:22:44   19.7188  25.8364 2019-05-10 16:22:44
# 2019-05-24 16:23:44   19.5625  25.8278 2019-05-10 16:23:44

# %%
moist['Week']=moist.index.weekofyear
moist['freq']=moist.index.freq
moist.head()
# Out:
#                      Humidity     Temp  Week  freq
# Time
# 2019-05-24 16:19:41   19.2812  25.5513    21  None
# 2019-05-24 16:20:42   19.3750  25.5064    21  None
# 2019-05-24 16:21:43   19.5000  25.8244    21  None
# 2019-05-24 16:22:44   19.7188  25.8364    21  None
# 2019-05-24 16:23:44   19.5625  25.8278    21  None

# %%
moist.loc['2019']
# Out:
#                      Humidity     Temp             WeekAgo
# Time
# 2019-05-24 16:19:41   19.2812  25.5513 2019-05-10 16:19:41
# 2019-05-24 16:20:42   19.3750  25.5064 2019-05-10 16:20:42
# 2019-05-24 16:21:43   19.5000  25.8244 2019-05-10 16:21:43
# 2019-05-24 16:22:44   19.7188  25.8364 2019-05-10 16:22:44
# 2019-05-24 16:23:44   19.5625  25.8278 2019-05-10 16:23:44
# 2019-05-24 16:24:45   19.5938  25.4686 2019-05-10 16:24:45
# 2019-05-24 16:25:46   19.6250  25.8313 2019-05-10 16:25:46
# 2019-05-24 16:26:47   19.5938  25.8296 2019-05-10 16:26:47
# 2019-05-24 16:27:48   19.4688  25.8227 2019-05-10 16:27:48
# 2019-05-24 16:28:49   19.3750  25.8175 2019-05-10 16:28:49
# 2019-05-24 16:29:50   19.2188  25.8089 2019-05-10 16:29:50
# 2019-05-24 16:30:50   19.2812  25.4516 2019-05-10 16:30:50
# 2019-05-24 16:31:51   19.3750  25.5064 2019-05-10 16:31:51
# 2019-05-24 16:32:52   19.2500  25.5495 2019-05-10 16:32:52
# 2019-05-24 16:33:53   19.2812  25.8123 2019-05-10 16:33:53
# ...

# %%
import matplotlib.pyplot as plt

moist['Humidity'].plot()

# %%
import pandas.tseries.offsets
import numpy as np
# moist['Time'].day_name()
# moist['Time']
s=moist.index.month_name()

# %%
import datetime
s=moist.tail(1)
# currentM=s.index.to_pydatetime
currentM=s.index
pastM=(s.WeekAgo).dt.date
anotherPast=(s.index +pd.offsets.Week(-1))
currentM=currentM.date
# diff=currentM-pastM
print('Now ', currentM, '\nPast ',pastM, '\n',anotherPast)
# print(pastM.dt.date)
# Out:
# Now  [datetime.date(2019, 5, 28)]
# Past  Time
# 2019-05-28 11:26:02    2019-05-14
# Name: WeekAgo, dtype: object
#  DatetimeIndex(['2019-05-21 11:26:02'], dtype='datetime64[ns]', name='Time', freq=None)

# %%
moist.loc[pastM.dt.date:currentM.dt.date]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-73be9db5f8ab> in <module>
# ----> 1 moist.loc[pastM.dt.date:currentM.dt.date]
#
# AttributeError: 'function' object has no attribute 'dt'
